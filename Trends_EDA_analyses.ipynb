# %% [markdown]
# # EDA and analyses of Google Trends data

# %%
from linearmodels.panel import PooledOLS, PanelOLS

import statsmodels.api as sm
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
import statsmodels.formula.api as smf

from statsmodels.iolib.summary2 import summary_col

# %%
trend_month_state = pd.read_csv("data/cleaned/trend_month_state.csv", index_col=0)
trend_month_DMA = pd.read_csv("data/cleaned/trend_month_DMA.csv", index_col=0)
trend_all_time_state = pd.read_csv("data/cleaned/trend_all_time_state.csv", index_col=0)
trend_all_time_DMA = pd.read_csv("data/cleaned/trend_all_time_DMA.csv", index_col=0)

# %%
trend_all_time_state.replace(0, np.nan, inplace = True)
trend_month_state.replace(0, np.nan, inplace = True)

# %% [markdown]
# ## EDA

# %%
trend_all_time_state.head()
# Out:
#               date_range       state  covid_conspiracy  covid_hoax  pizzagate  \
# 0  2020-03-01 2021-01-31     Alabama              52.0        38.0       80.0
# 1  2020-03-01 2021-01-31      Alaska              90.0        94.0       49.0
# 2  2020-03-01 2021-01-31     Arizona              63.0        48.0       79.0
# 3  2020-03-01 2021-01-31    Arkansas              51.0        46.0       79.0
# 4  2020-03-01 2021-01-31  California              54.0        49.0       56.0
#
#    plandemic  wuhan_lab
# 0       57.0       39.0
# 1       77.0       46.0
# 2       53.0       49.0
# 3       51.0       52.0
# 4       58.0       49.0

# %%
trend_all_time_state[
    ["covid_conspiracy", "covid_hoax", "pizzagate", "plandemic", "wuhan_lab"]
].corr(method="pearson")
# Out:
#                   covid_conspiracy  covid_hoax  pizzagate  plandemic  \
# covid_conspiracy          1.000000    0.253764  -0.120353   0.487821
# covid_hoax                0.253764    1.000000  -0.112811   0.317223
# pizzagate                -0.120353   -0.112811   1.000000  -0.239771
# plandemic                 0.487821    0.317223  -0.239771   1.000000
# wuhan_lab                 0.135147    0.234428  -0.300099   0.128978
#
#                   wuhan_lab
# covid_conspiracy   0.135147
# covid_hoax         0.234428
# pizzagate         -0.300099
# plandemic          0.128978
# wuhan_lab          1.000000

# %% [markdown]
# It turns out that popularity of COVID-related conspiracy theories is not strongly correlated with "pizzagate", which is not related to COVID-19 per se. Among all covid-19 related keywords, there is a positive, yet not necessarily strong correlation.

# %% [markdown]
# ### Principle component analyses

# %%
pca_pipe =  Pipeline([('inputer', SimpleImputer()), ('PCA', PCA(n_components=2))])
principalComponents = pca_pipe.fit_transform(
    trend_all_time_state[["covid_conspiracy", "covid_hoax", "plandemic", "wuhan_lab"]]
)
principalDf = pd.DataFrame(data=principalComponents)

# %%
pca_pipe["PCA"].explained_variance_ratio_
# Out:
# array([0.46055991, 0.23254269])

# %%
pca_pipe["PCA"].components_
# Out:
# array([[ 0.62681881,  0.47529325,  0.54963197,  0.28124579],
#        [-0.43683202,  0.43500537, -0.25854643,  0.74370818]])

# %% [markdown]
# ## Panel analyses

# %% [markdown]
# ## Develop an index

# %% [markdown]
# ### with "Wuhan Lab"

# %% [markdown]
# ### without "Wuhan Lab"

# %%
trend_all_time_state["misinformation_index"] = trend_all_time_state[["covid_hoax", "covid_conspiracy", "plandemic"]].mean(axis = 1)

# %%
trend_all_time_state.sort_values("misinformation_index", ascending = False)
# Out:
#                date_range                 state  covid_conspiracy  covid_hoax  \
# 1   2020-03-01 2021-01-31                Alaska              90.0        94.0
# 29  2020-03-01 2021-01-31         New Hampshire              92.0        78.0
# 45  2020-03-01 2021-01-31               Vermont              55.0       100.0
# 23  2020-03-01 2021-01-31             Minnesota              82.0        50.0
# 34  2020-03-01 2021-01-31          North Dakota             100.0        39.0
# 27  2020-03-01 2021-01-31              Nebraska              78.0        58.0
# 50  2020-03-01 2021-01-31               Wyoming              71.0         NaN
# 37  2020-03-01 2021-01-31                Oregon              70.0        65.0
# 5   2020-03-01 2021-01-31              Colorado              77.0        67.0
# 12  2020-03-01 2021-01-31                 Idaho              53.0        89.0
# 47  2020-03-01 2021-01-31            Washington              63.0        60.0
# 19  2020-03-01 2021-01-31                 Maine              70.0        46.0
# 11  2020-03-01 2021-01-31                Hawaii              78.0        54.0
# 41  2020-03-01 2021-01-31          South Dakota              58.0        61.0
# 31  2020-03-01 2021-01-31            New Mexico              59.0        84.0
# 26  2020-03-01 2021-01-31               Montana              27.0        67.0
# 8   2020-03-01 2021-01-31  District of Columbia              60.0        45.0
# 25  2020-03-01 2021-01-31              Missouri              70.0        54.0
# 44  2020-03-01 2021-01-31                  Utah              70.0        37.0
# 49  2020-03-01 2021-01-31             Wisconsin              70.0        49.0
# 13  2020-03-01 2021-01-31              Illinois              67.0        48.0
# 48  2020-03-01 2021-01-31         West Virginia              55.0        57.0
# 35  2020-03-01 2021-01-31                  Ohio              63.0        41.0
# 22  2020-03-01 2021-01-31              Michigan              54.0        48.0
# 15  2020-03-01 2021-01-31                  Iowa              38.0        55.0
# 39  2020-03-01 2021-01-31          Rhode Island              61.0        63.0
# 14  2020-03-01 2021-01-31               Indiana              48.0        67.0
# 38  2020-03-01 2021-01-31          Pennsylvania              48.0        48.0
# 17  2020-03-01 2021-01-31              Kentucky              50.0        53.0
# 42  2020-03-01 2021-01-31             Tennessee              55.0        52.0
# 2   2020-03-01 2021-01-31               Arizona              63.0        48.0
# 4   2020-03-01 2021-01-31            California              54.0        49.0
# 28  2020-03-01 2021-01-31                Nevada              46.0        62.0
# 21  2020-03-01 2021-01-31         Massachusetts              59.0        41.0
# 6   2020-03-01 2021-01-31           Connecticut              39.0        49.0
# 33  2020-03-01 2021-01-31        North Carolina              58.0        40.0
# 3   2020-03-01 2021-01-31              Arkansas              51.0        46.0
# 0   2020-03-01 2021-01-31               Alabama              52.0        38.0
# 30  2020-03-01 2021-01-31            New Jersey              46.0        36.0
# 36  2020-03-01 2021-01-31              Oklahoma              51.0        46.0
# 16  2020-03-01 2021-01-31                Kansas              39.0        41.0
# 20  2020-03-01 2021-01-31              Maryland              36.0        43.0
# 9   2020-03-01 2021-01-31               Florida              50.0        39.0
# 46  2020-03-01 2021-01-31              Virginia              39.0        43.0
# 18  2020-03-01 2021-01-31             Louisiana              58.0        29.0
# 32  2020-03-01 2021-01-31              New York              42.0        34.0
# 40  2020-03-01 2021-01-31        South Carolina              38.0        43.0
# 10  2020-03-01 2021-01-31               Georgia              36.0        38.0
# 43  2020-03-01 2021-01-31                 Texas              40.0        34.0
# 7   2020-03-01 2021-01-31              Delaware              17.0        60.0
# 24  2020-03-01 2021-01-31           Mississippi              34.0        28.0
#
#     pizzagate  plandemic  wuhan_lab  misinformation_index
# 1        49.0       77.0       46.0             87.000000
# 29       55.0       65.0       91.0             78.333333
# 45       48.0       79.0      100.0             78.000000
# 23       57.0       94.0       52.0             75.333333
# 34       54.0       85.0       38.0             74.666667
# 27       72.0       81.0       39.0             72.333333
# 50       61.0       72.0       32.0             71.500000
# 37       67.0       75.0       43.0             70.000000
# 5        63.0       66.0       35.0             70.000000
# 12       69.0       66.0       42.0             69.333333
# 47       62.0       81.0       53.0             68.000000
# 19       62.0       85.0       85.0             67.000000
# 11       70.0       67.0       55.0             66.333333
# 41       51.0       80.0       14.0             66.333333
# 31       72.0       55.0       31.0             66.000000
# 26       80.0      100.0       33.0             64.666667
# 8        28.0       85.0       79.0             63.333333
# 25       75.0       64.0       43.0             62.666667
# 44      100.0       77.0       44.0             61.333333
# 49       59.0       63.0       46.0             60.666667
# 13       67.0       64.0       56.0             59.666667
# 48       69.0       67.0       45.0             59.666667
# 35       71.0       74.0       49.0             59.333333
# 22       74.0       69.0       56.0             57.000000
# 15       59.0       78.0       40.0             57.000000
# 39       66.0       46.0       57.0             56.666667
# 14       77.0       55.0       55.0             56.666667
# 38       68.0       71.0       56.0             55.666667
# 17       77.0       63.0       54.0             55.333333
# 42       72.0       59.0       43.0             55.333333
# 2        79.0       53.0       49.0             54.666667
# 4        56.0       58.0       49.0             53.666667
# 28       74.0       50.0       42.0             52.666667
# 21       54.0       55.0       58.0             51.666667
# 6        48.0       63.0       64.0             50.333333
# 33       59.0       51.0       45.0             49.666667
# 3        79.0       51.0       52.0             49.333333
# 0        80.0       57.0       39.0             49.000000
# 30       58.0       64.0       56.0             48.666667
# 36       84.0       47.0       53.0             48.000000
# 16       64.0       62.0       32.0             47.333333
# 20       45.0       59.0       54.0             46.000000
# 9        59.0       45.0       44.0             44.666667
# 46       53.0       49.0       51.0             43.666667
# 18       79.0       43.0       39.0             43.333333
# 32       46.0       52.0       46.0             42.666667
# 40       55.0       43.0       36.0             41.333333
# 10       66.0       49.0       36.0             41.000000
# 43       72.0       45.0       38.0             39.666667
# 7        78.0       28.0       60.0             35.000000
# 24       80.0       31.0       35.0             31.000000

# %% [markdown]
# ## Regression analyses

# %% [markdown]
# ### Relationship between conspiracy theory popularity and compliance (mobility)

# %%
us_daily = pd.read_csv("data/cleaned/daily_df.csv", index_col=0)
us_daily["date"] = pd.to_datetime(us_daily["date"])
us_daily = us_daily.set_index("date")

# %%
us_monthly = us_daily.groupby([pd.Grouper(freq='M'), 'state']).mean()
us_monthly
# Out:
#                                positive  probableCases      negative  \
# date       state
# 2020-01-31 Florida             0.000000            NaN           NaN
#            Massachusetts            NaN            NaN           NaN
#            Virginia                 NaN            NaN           NaN
#            Washington          1.333333            NaN           NaN
# 2020-02-29 Florida             0.000000            NaN           NaN
# ...                                 ...            ...           ...
# 2021-02-28 Virginia       533521.941176  108944.411765           NaN
#            Washington     321918.647059   15809.117647           NaN
#            West Virginia  125328.235294   24920.941176  1.907528e+06
#            Wisconsin      602149.941176   51173.529412  2.543102e+06
#            Wyoming         52792.588235    7784.411765  1.741915e+05
#
#                              pending  totalTestResults  hospitalizedCurrently  \
# date       state
# 2020-01-31 Florida               NaN      2.000000e+00                    NaN
#            Massachusetts         NaN      2.700000e+00                    NaN
#            Virginia              NaN               NaN                    NaN
#            Washington            NaN      0.000000e+00                    NaN
# 2020-02-29 Florida               NaN      1.024138e+01                    NaN
# ...                              ...               ...                    ...
# 2021-02-28 Virginia       251.411765      5.468171e+06            2196.411765
#            Washington            NaN      4.761709e+06             740.529412
#            West Virginia         NaN      2.032857e+06             373.470588
#            Wisconsin       38.176471      6.377024e+06             531.882353
#            Wyoming               NaN      6.367162e+05              43.176471
#
#                           hospitalizedCumulative  inIcuCurrently  \
# date       state
# 2020-01-31 Florida                           NaN             NaN
#            Massachusetts                     NaN             NaN
#            Virginia                          NaN             NaN
#            Washington                        NaN             NaN
# 2020-02-29 Florida                           NaN             NaN
# ...                                          ...             ...
# 2021-02-28 Virginia                 22329.588235      446.235294
#            Washington               18326.117647      175.411765
#            West Virginia                     NaN      100.058824
#            Wisconsin                24978.058824      137.176471
#            Wyoming                   1315.470588             NaN
#
#                           inIcuCumulative  onVentilatorCurrently  ...  \
# date       state                                                  ...
# 2020-01-31 Florida                    NaN                    NaN  ...
#            Massachusetts              NaN                    NaN  ...
#            Virginia                   NaN                    NaN  ...
#            Washington                 NaN                    NaN  ...
# 2020-02-29 Florida                    NaN                    NaN  ...
# ...                                   ...                    ...  ...
# 2021-02-28 Virginia                   NaN             280.117647  ...
#            Washington                 NaN              69.176471  ...
#            West Virginia              NaN              47.000000  ...
#            Wisconsin          2206.823529                    NaN  ...
#            Wyoming                    NaN                    NaN  ...
#
#                           C7_Restrictions on internal movement  C7_Flag  \
# date       state
# 2020-01-31 Florida                                         0.0      NaN
#            Massachusetts                                   0.0      NaN
#            Virginia                                        0.0      NaN
#            Washington                                      0.0      NaN
# 2020-02-29 Florida                                         0.0      NaN
# ...                                                        ...      ...
# 2021-02-28 Virginia                                        0.0      NaN
#            Washington                                      1.0      0.0
#            West Virginia                                   1.0      1.0
#            Wisconsin                                       1.0      1.0
#            Wyoming                                         0.0      NaN
#
#                           C8_International travel controls  ConfirmedCases  \
# date       state
# 2020-01-31 Florida                                     0.0        0.000000
#            Massachusetts                               0.0        0.300000
#            Virginia                                    0.0        0.000000
#            Washington                                  0.0        1.000000
# 2020-02-29 Florida                                     0.0        0.000000
# ...                                                    ...             ...
# 2021-02-28 Virginia                                    0.0   533521.941176
#            Washington                                  2.0   323048.647059
#            West Virginia                               2.0   125328.235294
#            Wisconsin                                   0.0   602149.941176
#            Wyoming                                     0.0    52792.588235
#
#                           ConfirmedDeaths  StringencyIndex  \
# date       state
# 2020-01-31 Florida               0.000000         0.000000
#            Massachusetts         0.000000         2.220000
#            Virginia              0.000000         0.000000
#            Washington            0.000000         0.000000
# 2020-02-29 Florida               0.000000         0.958621
# ...                                   ...              ...
# 2021-02-28 Virginia           6835.823529        53.373529
#            Washington         4541.058824        62.960000
#            West Virginia      2144.235294        46.300000
#            Wisconsin          6648.176471        47.690000
#            Wyoming             636.294118        48.514667
#
#                           GovernmentResponseIndex  ContainmentHealthIndex  \
# date       state
# 2020-01-31 Florida                       0.000000                0.000000
#            Massachusetts                 1.332000                1.536000
#            Virginia                      0.000000                0.000000
#            Washington                    3.394211                3.913684
# 2020-02-29 Florida                       0.574138                0.663793
# ...                                           ...                     ...
# 2021-02-28 Virginia                     53.283529               57.631176
#            Washington                   63.220000               61.410000
#            West Virginia                50.110000               57.820000
#            Wisconsin                    54.112000               58.588000
#            Wyoming                      49.776667               57.435333
#
#                             pop_2019  GDP_2019
# date       state
# 2020-01-31 Florida        21477737.0  950759.1
#            Massachusetts   6892503.0  518718.6
#            Virginia        8535519.0  485998.4
#            Washington      7614893.0  531224.1
# 2020-02-29 Florida        21477737.0  950759.1
# ...                              ...       ...
# 2021-02-28 Virginia        8535519.0  485998.4
#            Washington      7614893.0  531224.1
#            West Virginia   1792147.0   72161.5
#            Wisconsin       5822434.0  305874.4
#            Wyoming          578759.0   39306.6
#
# [683 rows x 74 columns]

# %%
us_monthly = pd.DataFrame(us_monthly.to_records())

# %%
trend_month_state["date"] = pd.to_datetime(trend_month_state["date_range"].str.slice(start = -10))

# %%
trend_month_state = trend_month_state.drop("date_range", axis = 1)

# %%
trend_month_state
# Out:
#              state  covid_conspiracy  covid_hoax  pizzagate  plandemic  \
# 0          Alabama              29.0        10.0       76.0        NaN
# 1           Alaska              73.0        80.0       97.0        NaN
# 2          Arizona              34.0        25.0       60.0        NaN
# 3         Arkansas             100.0         NaN       11.0        NaN
# 4       California              41.0        18.0       44.0       18.0
# ..             ...               ...         ...        ...        ...
# 556       Virginia              19.0        14.0       10.0        5.0
# 557     Washington              23.0         4.0       12.0        NaN
# 558  West Virginia               NaN         NaN       35.0        NaN
# 559      Wisconsin              11.0         6.0       45.0        8.0
# 560        Wyoming               NaN         NaN        NaN      100.0
#
#      wuhan_lab       date
# 0         33.0 2020-03-31
# 1        100.0 2020-03-31
# 2         31.0 2020-03-31
# 3         34.0 2020-03-31
# 4         42.0 2020-03-31
# ..         ...        ...
# 556       14.0 2021-01-31
# 557       52.0 2021-01-31
# 558        NaN 2021-01-31
# 559        NaN 2021-01-31
# 560        NaN 2021-01-31
#
# [561 rows x 7 columns]

# %%
us_monthly = pd.merge(trend_month_state, us_monthly, on = ["state", "date"], how = "left")

# %%
us_monthly = us_monthly.set_index("date")

# %% [markdown]
# #### Cross-sectional

# %%
us_cross_sectional = us_daily.loc[(us_daily.index >= "2020-03-01") & (us_daily.index <= "2021-01-31")].groupby("state").mean()

# %%
us_cross_sectional.head()
# Out:
#                      positive  probableCases      negative    pending  \
# state
# Alabama         136385.302115   27217.243902  7.606047e+05  33.000000
# Alaska           13197.732087            NaN           NaN   8.500000
# American Samoa       0.000000            NaN  1.204010e+03  10.500000
# Arizona         201980.850299    9544.242553  1.006278e+06  44.240000
# Arkansas         80232.936747   20588.403974  7.651620e+05  47.588235
#
#                 totalTestResults  hospitalizedCurrently  \
# state
# Alabama             8.698175e+05            1171.560510
# Alaska              4.563348e+05              57.076125
# American Samoa      1.147922e+03                    NaN
# Arizona             1.984202e+06            1937.880952
# Arkansas            8.360406e+05             526.895570
#
#                 hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# state
# Alabama                   15107.151815             NaN      1471.101351
# Alaska                      346.443769             NaN              NaN
# American Samoa                     NaN             NaN              NaN
# Arizona                   16354.311377      516.486395              NaN
# Arkansas                   4944.758170      313.140845        43.000000
#
#                 onVentilatorCurrently  ...  \
# state                                  ...
# Alabama                           NaN  ...
# Alaska                       7.689516  ...
# American Samoa                    NaN  ...
# Arizona                    337.914966  ...
# Arkansas                    98.476038  ...
#
#                 C7_Restrictions on internal movement   C7_Flag  \
# state
# Alabama                                     0.000000       NaN
# Alaska                                      1.692771  0.922581
# American Samoa                                   NaN       NaN
# Arizona                                     0.221557  1.000000
# Arkansas                                    0.246988  1.000000
#
#                 C8_International travel controls  ConfirmedCases  \
# state
# Alabama                                 0.000000   136602.320242
# Alaska                                  1.933735    13451.298193
# American Samoa                               NaN             NaN
# Arizona                                 0.221557   201990.272455
# Arkansas                                0.246988    80259.963855
#
#                 ConfirmedDeaths  StringencyIndex  GovernmentResponseIndex  \
# state
# Alabama             2154.471299        36.371843                40.989245
# Alaska                64.530120        53.172440                52.371175
# American Samoa              NaN              NaN                      NaN
# Arizona             4162.688623        42.069641                47.662425
# Arkansas            1261.433735        44.011807                44.869970
#
#                 ContainmentHealthIndex   pop_2019  GDP_2019
# state
# Alabama                      43.211027  4903185.0  202940.3
# Alaska                       52.854880   731545.0   54442.9
# American Samoa                     NaN        NaN       NaN
# Arizona                      46.335539  7278717.0  321431.9
# Arkansas                     47.252952  3017804.0  119443.4
#
# [5 rows x 74 columns]

# %%
trend_all_time_state.drop("date_range", axis = 1)
# Out:
#                    state  covid_conspiracy  covid_hoax  pizzagate  plandemic  \
# 0                Alabama              52.0        38.0       80.0       57.0
# 1                 Alaska              90.0        94.0       49.0       77.0
# 2                Arizona              63.0        48.0       79.0       53.0
# 3               Arkansas              51.0        46.0       79.0       51.0
# 4             California              54.0        49.0       56.0       58.0
# 5               Colorado              77.0        67.0       63.0       66.0
# 6            Connecticut              39.0        49.0       48.0       63.0
# 7               Delaware              17.0        60.0       78.0       28.0
# 8   District of Columbia              60.0        45.0       28.0       85.0
# 9                Florida              50.0        39.0       59.0       45.0
# 10               Georgia              36.0        38.0       66.0       49.0
# 11                Hawaii              78.0        54.0       70.0       67.0
# 12                 Idaho              53.0        89.0       69.0       66.0
# 13              Illinois              67.0        48.0       67.0       64.0
# 14               Indiana              48.0        67.0       77.0       55.0
# 15                  Iowa              38.0        55.0       59.0       78.0
# 16                Kansas              39.0        41.0       64.0       62.0
# 17              Kentucky              50.0        53.0       77.0       63.0
# 18             Louisiana              58.0        29.0       79.0       43.0
# 19                 Maine              70.0        46.0       62.0       85.0
# 20              Maryland              36.0        43.0       45.0       59.0
# 21         Massachusetts              59.0        41.0       54.0       55.0
# 22              Michigan              54.0        48.0       74.0       69.0
# 23             Minnesota              82.0        50.0       57.0       94.0
# 24           Mississippi              34.0        28.0       80.0       31.0
# 25              Missouri              70.0        54.0       75.0       64.0
# 26               Montana              27.0        67.0       80.0      100.0
# 27              Nebraska              78.0        58.0       72.0       81.0
# 28                Nevada              46.0        62.0       74.0       50.0
# 29         New Hampshire              92.0        78.0       55.0       65.0
# 30            New Jersey              46.0        36.0       58.0       64.0
# 31            New Mexico              59.0        84.0       72.0       55.0
# 32              New York              42.0        34.0       46.0       52.0
# 33        North Carolina              58.0        40.0       59.0       51.0
# 34          North Dakota             100.0        39.0       54.0       85.0
# 35                  Ohio              63.0        41.0       71.0       74.0
# 36              Oklahoma              51.0        46.0       84.0       47.0
# 37                Oregon              70.0        65.0       67.0       75.0
# 38          Pennsylvania              48.0        48.0       68.0       71.0
# 39          Rhode Island              61.0        63.0       66.0       46.0
# 40        South Carolina              38.0        43.0       55.0       43.0
# 41          South Dakota              58.0        61.0       51.0       80.0
# 42             Tennessee              55.0        52.0       72.0       59.0
# 43                 Texas              40.0        34.0       72.0       45.0
# 44                  Utah              70.0        37.0      100.0       77.0
# 45               Vermont              55.0       100.0       48.0       79.0
# 46              Virginia              39.0        43.0       53.0       49.0
# 47            Washington              63.0        60.0       62.0       81.0
# 48         West Virginia              55.0        57.0       69.0       67.0
# 49             Wisconsin              70.0        49.0       59.0       63.0
# 50               Wyoming              71.0         NaN       61.0       72.0
#
#     wuhan_lab  misinformation_index
# 0        39.0             49.000000
# 1        46.0             87.000000
# 2        49.0             54.666667
# 3        52.0             49.333333
# 4        49.0             53.666667
# 5        35.0             70.000000
# 6        64.0             50.333333
# 7        60.0             35.000000
# 8        79.0             63.333333
# 9        44.0             44.666667
# 10       36.0             41.000000
# 11       55.0             66.333333
# 12       42.0             69.333333
# 13       56.0             59.666667
# 14       55.0             56.666667
# 15       40.0             57.000000
# 16       32.0             47.333333
# 17       54.0             55.333333
# 18       39.0             43.333333
# 19       85.0             67.000000
# 20       54.0             46.000000
# 21       58.0             51.666667
# 22       56.0             57.000000
# 23       52.0             75.333333
# 24       35.0             31.000000
# 25       43.0             62.666667
# 26       33.0             64.666667
# 27       39.0             72.333333
# 28       42.0             52.666667
# 29       91.0             78.333333
# 30       56.0             48.666667
# 31       31.0             66.000000
# 32       46.0             42.666667
# 33       45.0             49.666667
# 34       38.0             74.666667
# 35       49.0             59.333333
# 36       53.0             48.000000
# 37       43.0             70.000000
# 38       56.0             55.666667
# 39       57.0             56.666667
# 40       36.0             41.333333
# 41       14.0             66.333333
# 42       43.0             55.333333
# 43       38.0             39.666667
# 44       44.0             61.333333
# 45      100.0             78.000000
# 46       51.0             43.666667
# 47       53.0             68.000000
# 48       45.0             59.666667
# 49       46.0             60.666667
# 50       32.0             71.500000

# %%
us_cross_sectional = pd.merge(us_cross_sectional, trend_all_time_state.drop("date_range", axis = 1), on="state")

# %%
us_cross_sectional[
    [
        "covid_conspiracy",
        "covid_hoax",
        "pizzagate",
        "plandemic",
        "wuhan_lab",
        "misinformation_index",
        "retail_and_recreation_percent_change_from_baseline",
        "grocery_and_pharmacy_percent_change_from_baseline",
        "parks_percent_change_from_baseline",
        "transit_stations_percent_change_from_baseline",
        "workplaces_percent_change_from_baseline",
        "residential_percent_change_from_baseline",
    ]
].corr()
# Out:
#                                                     covid_conspiracy  \
# covid_conspiracy                                            1.000000
# covid_hoax                                                  0.253764
# pizzagate                                                  -0.120353
# plandemic                                                   0.487821
# wuhan_lab                                                   0.135147
# misinformation_index                                        0.784104
# retail_and_recreation_percent_change_from_baseline         -0.010402
# grocery_and_pharmacy_percent_change_from_baseline          -0.019829
# parks_percent_change_from_baseline                          0.178510
# transit_stations_percent_change_from_baseline              -0.049109
# workplaces_percent_change_from_baseline                     0.068361
# residential_percent_change_from_baseline                   -0.004050
#
#                                                     covid_hoax  pizzagate  \
# covid_conspiracy                                      0.253764  -0.120353
# covid_hoax                                            1.000000  -0.112811
# pizzagate                                            -0.112811   1.000000
# plandemic                                             0.317223  -0.239771
# wuhan_lab                                             0.234428  -0.300099
# misinformation_index                                  0.691606  -0.208420
# retail_and_recreation_percent_change_from_baseline    0.230847   0.401191
# grocery_and_pharmacy_percent_change_from_baseline     0.243772   0.301877
# parks_percent_change_from_baseline                    0.296104  -0.004714
# transit_stations_percent_change_from_baseline         0.127058   0.401519
# workplaces_percent_change_from_baseline               0.134546   0.370558
# residential_percent_change_from_baseline             -0.135672  -0.483044
#
#                                                     plandemic  wuhan_lab  \
# covid_conspiracy                                     0.487821   0.135147
# covid_hoax                                           0.317223   0.234428
# pizzagate                                           -0.239771  -0.300099
# plandemic                                            1.000000   0.128978
# wuhan_lab                                            0.128978   1.000000
# misinformation_index                                 0.787842   0.205043
# retail_and_recreation_percent_change_from_baseline   0.018000  -0.321172
# grocery_and_pharmacy_percent_change_from_baseline    0.221099  -0.389766
# parks_percent_change_from_baseline                   0.445000   0.021916
# transit_stations_percent_change_from_baseline        0.070676  -0.447594
# workplaces_percent_change_from_baseline              0.057921  -0.396473
# residential_percent_change_from_baseline            -0.044378   0.419193
#
#                                                     misinformation_index  \
# covid_conspiracy                                                0.784104
# covid_hoax                                                      0.691606
# pizzagate                                                      -0.208420
# plandemic                                                       0.787842
# wuhan_lab                                                       0.205043
# misinformation_index                                            1.000000
# retail_and_recreation_percent_change_from_baseline              0.114625
# grocery_and_pharmacy_percent_change_from_baseline               0.204477
# parks_percent_change_from_baseline                              0.407142
# transit_stations_percent_change_from_baseline                   0.081769
# workplaces_percent_change_from_baseline                         0.129428
# residential_percent_change_from_baseline                       -0.095174
#
#                                                     retail_and_recreation_percent_change_from_baseline  \
# covid_conspiracy                                                                            -0.010402
# covid_hoax                                                                                   0.230847
# pizzagate                                                                                    0.401191
# plandemic                                                                                    0.018000
# wuhan_lab                                                                                   -0.321172
# misinformation_index                                                                         0.114625
# retail_and_recreation_percent_change_from_baseline                                           1.000000
# grocery_and_pharmacy_percent_change_from_baseline                                            0.875769
# parks_percent_change_from_baseline                                                           0.626384
# transit_stations_percent_change_from_baseline                                                0.861872
# workplaces_percent_change_from_baseline                                                      0.919708
# residential_percent_change_from_baseline                                                    -0.915799
#
#                                                     grocery_and_pharmacy_percent_change_from_baseline  \
# covid_conspiracy                                                                            -0.019829
# covid_hoax                                                                                   0.243772
# pizzagate                                                                                    0.301877
# plandemic                                                                                    0.221099
# wuhan_lab                                                                                   -0.389766
# misinformation_index                                                                         0.204477
# retail_and_recreation_percent_change_from_baseline                                           0.875769
# grocery_and_pharmacy_percent_change_from_baseline                                            1.000000
# parks_percent_change_from_baseline                                                           0.690662
# transit_stations_percent_change_from_baseline                                                0.845603
# workplaces_percent_change_from_baseline                                                      0.827409
# residential_percent_change_from_baseline                                                    -0.835714
#
#                                                     parks_percent_change_from_baseline  \
# covid_conspiracy                                                              0.178510
# covid_hoax                                                                    0.296104
# pizzagate                                                                    -0.004714
# plandemic                                                                     0.445000
# wuhan_lab                                                                     0.021916
# misinformation_index                                                          0.407142
# retail_and_recreation_percent_change_from_baseline                            0.626384
# grocery_and_pharmacy_percent_change_from_baseline                             0.690662
# parks_percent_change_from_baseline                                            1.000000
# transit_stations_percent_change_from_baseline                                 0.491450
# workplaces_percent_change_from_baseline                                       0.534746
# residential_percent_change_from_baseline                                     -0.475357
#
#                                                     transit_stations_percent_change_from_baseline  \
# covid_conspiracy                                                                        -0.049109
# covid_hoax                                                                               0.127058
# pizzagate                                                                                0.401519
# plandemic                                                                                0.070676
# wuhan_lab                                                                               -0.447594
# misinformation_index                                                                     0.081769
# retail_and_recreation_percent_change_from_baseline                                       0.861872
# grocery_and_pharmacy_percent_change_from_baseline                                        0.845603
# parks_percent_change_from_baseline                                                       0.491450
# transit_stations_percent_change_from_baseline                                            1.000000
# workplaces_percent_change_from_baseline                                                  0.901898
# residential_percent_change_from_baseline                                                -0.923143
#
#                                                     workplaces_percent_change_from_baseline  \
# covid_conspiracy                                                                   0.068361
# covid_hoax                                                                         0.134546
# pizzagate                                                                          0.370558
# plandemic                                                                          0.057921
# wuhan_lab                                                                         -0.396473
# misinformation_index                                                               0.129428
# retail_and_recreation_percent_change_from_baseline                                 0.919708
# grocery_and_pharmacy_percent_change_from_baseline                                  0.827409
# parks_percent_change_from_baseline                                                 0.534746
# transit_stations_percent_change_from_baseline                                      0.901898
# workplaces_percent_change_from_baseline                                            1.000000
# residential_percent_change_from_baseline                                          -0.949312
#
#                                                     residential_percent_change_from_baseline
# covid_conspiracy                                                                   -0.004050
# covid_hoax                                                                         -0.135672
# pizzagate                                                                          -0.483044
# plandemic                                                                          -0.044378
# wuhan_lab                                                                           0.419193
# misinformation_index                                                               -0.095174
# retail_and_recreation_percent_change_from_baseline                                 -0.915799
# grocery_and_pharmacy_percent_change_from_baseline                                  -0.835714
# parks_percent_change_from_baseline                                                 -0.475357
# transit_stations_percent_change_from_baseline                                      -0.923143
# workplaces_percent_change_from_baseline                                            -0.949312
# residential_percent_change_from_baseline                                            1.000000

# %%
us_cross_sectional.columns
# Out:
# Index(['state', 'positive', 'probableCases', 'negative', 'pending',
#        'totalTestResults', 'hospitalizedCurrently', 'hospitalizedCumulative',
#        'inIcuCurrently', 'inIcuCumulative', 'onVentilatorCurrently',
#        'onVentilatorCumulative', 'recovered', 'totalTestsViral',
#        'positiveTestsViral', 'negativeTestsViral', 'positiveCasesViral',
#        'deathConfirmed', 'deathProbable', 'totalTestEncountersViral',
#        'totalTestsPeopleViral', 'totalTestsAntibody', 'positiveTestsAntibody',
#        'negativeTestsAntibody', 'totalTestsPeopleAntibody',
#        'positiveTestsPeopleAntibody', 'negativeTestsPeopleAntibody',
#        'totalTestsPeopleAntigen', 'positiveTestsPeopleAntigen',
#        'totalTestsAntigen', 'positiveTestsAntigen', 'fips', 'positiveIncrease',
#        'negativeIncrease', 'total', 'totalTestResultsIncrease', 'posNeg',
#        'dataQualityGrade', 'deathIncrease', 'hospitalizedIncrease',
#        'commercialScore', 'negativeRegularScore', 'negativeScore',
#        'positiveScore', 'score', 'grade',
#        'retail_and_recreation_percent_change_from_baseline',
#        'grocery_and_pharmacy_percent_change_from_baseline',
#        'parks_percent_change_from_baseline',
#        'transit_stations_percent_change_from_baseline',
#        'workplaces_percent_change_from_baseline',
#        'residential_percent_change_from_baseline',
#        'non_residential_percent_change_from_baseline', 'C1_School closing',
#        'C1_Flag', 'C2_Workplace closing', 'C2_Flag', 'C3_Cancel public events',
#        'C3_Flag', 'C4_Restrictions on gatherings', 'C4_Flag',
#        'C5_Close public transport', 'C5_Flag', 'C6_Stay at home requirements',
#        'C6_Flag', 'C7_Restrictions on internal movement', 'C7_Flag',
#        'C8_International travel controls', 'ConfirmedCases', 'ConfirmedDeaths',
#        'StringencyIndex', 'GovernmentResponseIndex', 'ContainmentHealthIndex',
#        'pop_2019', 'GDP_2019', 'covid_conspiracy', 'covid_hoax', 'pizzagate',
#        'plandemic', 'wuhan_lab', 'misinformation_index'],
#       dtype='object')

# %%
us_cross_sectional[["state", "non_residential_percent_change_from_baseline"]].sort_values("non_residential_percent_change_from_baseline")
# Out:
#                    state  non_residential_percent_change_from_baseline
# 8   District of Columbia                                    -45.761562
# 11                Hawaii                                    -39.502994
# 4             California                                    -26.760479
# 9                Florida                                    -26.512760
# 28                Nevada                                    -24.681682
# 2                Arizona                                    -21.844910
# 32              New York                                    -21.045833
# 43                 Texas                                    -18.492537
# 18             Louisiana                                    -16.592749
# 21         Massachusetts                                    -16.407715
# 31            New Mexico                                    -12.982583
# 10               Georgia                                    -12.867665
# 13              Illinois                                    -11.580240
# 5               Colorado                                    -11.531138
# 7               Delaware                                    -11.530221
# 47            Washington                                    -11.477151
# 20              Maryland                                    -11.125526
# 30            New Jersey                                    -10.494362
# 46              Virginia                                     -9.843917
# 38          Pennsylvania                                     -8.487761
# 33        North Carolina                                     -8.272455
# 6            Connecticut                                     -7.275529
# 37                Oregon                                     -6.916168
# 45               Vermont                                     -5.500348
# 0                Alabama                                     -5.309366
# 40        South Carolina                                     -5.202395
# 24           Mississippi                                     -4.408459
# 23             Minnesota                                     -3.924699
# 42             Tennessee                                     -1.428228
# 36              Oklahoma                                     -0.852568
# 48         West Virginia                                     -0.762952
# 39          Rhode Island                                     -0.109496
# 34          North Dakota                                      0.845921
# 25              Missouri                                      1.022356
# 44                  Utah                                      1.108761
# 17              Kentucky                                      1.787801
# 1                 Alaska                                      3.100000
# 3               Arkansas                                      3.574398
# 29         New Hampshire                                      3.982784
# 27              Nebraska                                      4.295401
# 16                Kansas                                      4.513102
# 22              Michigan                                      6.035015
# 35                  Ohio                                      7.048649
# 14               Indiana                                      8.690801
# 19                 Maine                                      9.477946
# 49             Wisconsin                                      9.902090
# 26               Montana                                     10.717271
# 15                  Iowa                                     11.773645
# 12                 Idaho                                     12.048489
# 50               Wyoming                                     15.950445
# 41          South Dakota                                     24.796626

# %%
cross_sectional_reg_1 = smf.ols('non_residential_percent_change_from_baseline ~ misinformation_index', data=us_cross_sectional).fit()
cross_sectional_reg_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                          OLS Regression Results
# ========================================================================================================
# Dep. Variable:     non_residential_percent_change_from_baseline   R-squared:                       0.090
# Model:                                                      OLS   Adj. R-squared:                  0.071
# Method:                                           Least Squares   F-statistic:                     4.827
# Date:                                          Sat, 20 Feb 2021   Prob (F-statistic):             0.0328
# Time:                                                  09:43:41   Log-Likelihood:                -202.52
# No. Observations:                                            51   AIC:                             409.0
# Df Residuals:                                                49   BIC:                             412.9
# Df Model:                                                     1
# Covariance Type:                                      nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept              -24.7055      8.947     -2.761      0.008     -42.685      -6.726
# misinformation_index     0.3350      0.153      2.197      0.033       0.029       0.642
# ==============================================================================
# Omnibus:                       12.415   Durbin-Watson:                   1.773
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               13.896
# Skew:                          -0.945   Prob(JB):                     0.000960
# Kurtosis:                       4.723   Cond. No.                         286.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
cross_sectional_reg_2 = smf.ols('non_residential_percent_change_from_baseline ~ misinformation_index + StringencyIndex', data=us_cross_sectional).fit()
cross_sectional_reg_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                          OLS Regression Results
# ========================================================================================================
# Dep. Variable:     non_residential_percent_change_from_baseline   R-squared:                       0.372
# Model:                                                      OLS   Adj. R-squared:                  0.346
# Method:                                           Least Squares   F-statistic:                     13.94
# Date:                                          Sat, 20 Feb 2021   Prob (F-statistic):           1.77e-05
# Time:                                                  09:56:37   Log-Likelihood:                -184.81
# No. Observations:                                            50   AIC:                             375.6
# Df Residuals:                                                47   BIC:                             381.3
# Df Model:                                                     2
# Covariance Type:                                      nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                3.9674      9.838      0.403      0.689     -15.825      23.760
# misinformation_index     0.3698      0.117      3.150      0.003       0.134       0.606
# StringencyIndex         -0.5931      0.140     -4.238      0.000      -0.875      -0.312
# ==============================================================================
# Omnibus:                        3.227   Durbin-Watson:                   2.166
# Prob(Omnibus):                  0.199   Jarque-Bera (JB):                2.530
# Skew:                          -0.547   Prob(JB):                        0.282
# Kurtosis:                       3.132   Cond. No.                         533.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
cross_sectional_reg_plandemic = smf.ols('non_residential_percent_change_from_baseline ~ plandemic + StringencyIndex', data=us_cross_sectional).fit()
cross_sectional_reg_plandemic.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                          OLS Regression Results
# ========================================================================================================
# Dep. Variable:     non_residential_percent_change_from_baseline   R-squared:                       0.397
# Model:                                                      OLS   Adj. R-squared:                  0.372
# Method:                                           Least Squares   F-statistic:                     15.50
# Date:                                          Sat, 20 Feb 2021   Prob (F-statistic):           6.75e-06
# Time:                                                  10:09:49   Log-Likelihood:                -183.78
# No. Observations:                                            50   AIC:                             373.6
# Df Residuals:                                                47   BIC:                             379.3
# Df Model:                                                     2
# Covariance Type:                                      nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           1.9451      9.658      0.201      0.841     -17.484      21.375
# plandemic           0.3284      0.094      3.507      0.001       0.140       0.517
# StringencyIndex    -0.5406      0.138     -3.920      0.000      -0.818      -0.263
# ==============================================================================
# Omnibus:                        1.501   Durbin-Watson:                   2.404
# Prob(Omnibus):                  0.472   Jarque-Bera (JB):                1.368
# Skew:                          -0.390   Prob(JB):                        0.505
# Kurtosis:                       2.779   Cond. No.                         564.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
cross_sectional_reg_covid_hoax = smf.ols('non_residential_percent_change_from_baseline ~ covid_hoax + StringencyIndex', data=us_cross_sectional).fit()

# %%
cross_sectional_reg_covid_hoax.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                          OLS Regression Results
# ========================================================================================================
# Dep. Variable:     non_residential_percent_change_from_baseline   R-squared:                       0.354
# Model:                                                      OLS   Adj. R-squared:                  0.326
# Method:                                           Least Squares   F-statistic:                     12.59
# Date:                                          Sat, 20 Feb 2021   Prob (F-statistic):           4.36e-05
# Time:                                                  10:09:53   Log-Likelihood:                -180.88
# No. Observations:                                            49   AIC:                             367.8
# Df Residuals:                                                46   BIC:                             373.4
# Df Model:                                                     2
# Covariance Type:                                      nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          13.6726      8.057      1.697      0.096      -2.546      29.892
# covid_hoax          0.2577      0.091      2.830      0.007       0.074       0.441
# StringencyIndex    -0.6409      0.141     -4.534      0.000      -0.925      -0.356
# ==============================================================================
# Omnibus:                        3.505   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.173   Jarque-Bera (JB):                2.598
# Skew:                          -0.326   Prob(JB):                        0.273
# Kurtosis:                       3.920   Cond. No.                         418.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
cross_sectional_reg_covid_conspiracy = smf.ols('non_residential_percent_change_from_baseline ~ covid_conspiracy + StringencyIndex', data=us_cross_sectional).fit()
cross_sectional_reg_covid_conspiracy.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                          OLS Regression Results
# ========================================================================================================
# Dep. Variable:     non_residential_percent_change_from_baseline   R-squared:                       0.250
# Model:                                                      OLS   Adj. R-squared:                  0.218
# Method:                                           Least Squares   F-statistic:                     7.818
# Date:                                          Sat, 20 Feb 2021   Prob (F-statistic):            0.00117
# Time:                                                  10:09:53   Log-Likelihood:                -189.27
# No. Observations:                                            50   AIC:                             384.5
# Df Residuals:                                                47   BIC:                             390.3
# Df Model:                                                     2
# Covariance Type:                                      nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           20.8203      9.606      2.167      0.035       1.495      40.146
# covid_conspiracy     0.0726      0.093      0.783      0.437      -0.114       0.259
# StringencyIndex     -0.5883      0.153     -3.841      0.000      -0.896      -0.280
# ==============================================================================
# Omnibus:                        1.391   Durbin-Watson:                   2.279
# Prob(Omnibus):                  0.499   Jarque-Bera (JB):                1.197
# Skew:                          -0.371   Prob(JB):                        0.550
# Kurtosis:                       2.848   Cond. No.                         475.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
print(summary_col([cross_sectional_reg_1,cross_sectional_reg_2],stars=True,float_format='%0.2f').as_latex())
# Out:
# \begin{table}
# \caption{}
# \label{}
# \begin{center}
# \begin{tabular}{llllll}
# \hline
#                       & non\_residential\_percent\_change\_from\_baseline I & non\_residential\_percent\_change\_from\_baseline II & non\_residential\_percent\_change\_from\_baseline III & non\_residential\_percent\_change\_from\_baseline IIII & non\_residential\_percent\_change\_from\_baseline IIIII  \\
# \hline
# Intercept             & -24.71***                                           & 3.97                                                 & 1.95                                                  & 13.67*                                                 & 20.82**                                                  \\
#                       & (8.95)                                              & (9.84)                                               & (9.66)                                                & (8.06)                                                 & (9.61)                                                   \\
# R-squared             & 0.09                                                & 0.37                                                 & 0.40                                                  & 0.35                                                   & 0.25                                                     \\
# R-squared Adj.        & 0.07                                                & 0.35                                                 & 0.37                                                  & 0.33                                                   & 0.22                                                     \\
# StringencyIndex       &                                                     & -0.59***                                             & -0.54***                                              & -0.64***                                               & -0.59***                                                 \\
#                       &                                                     & (0.14)                                               & (0.14)                                                & (0.14)                                                 & (0.15)                                                   \\
# covid\_conspiracy     &                                                     &                                                      &                                                       &                                                        & 0.07                                                     \\
#                       &                                                     &                                                      &                                                       &                                                        & (0.09)                                                   \\
# covid\_hoax           &                                                     &                                                      &                                                       & 0.26***                                                &                                                          \\
#                       &                                                     &                                                      &                                                       & (0.09)                                                 &                                                          \\
# misinformation\_index & 0.34**                                              & 0.37***                                              &                                                       &                                                        &                                                          \\
#                       & (0.15)                                              & (0.12)                                               &                                                       &                                                        &                                                          \\
# plandemic             &                                                     &                                                      & 0.33***                                               &                                                        &                                                          \\
#                       &                                                     &                                                      & (0.09)                                                &                                                        &                                                          \\
# \hline
# \end{tabular}
# \end{center}
# \end{table}

# %%
print(summary_col([cross_sectional_reg_plandemic, cross_sectional_reg_covid_hoax, cross_sectional_reg_covid_conspiracy],stars=True,float_format='%0.2f').as_latex())
# Out:
# \begin{table}
# \caption{}
# \label{}
# \begin{center}
# \begin{tabular}{llll}
# \hline
#                   & non\_residential\_percent\_change\_from\_baseline I & non\_residential\_percent\_change\_from\_baseline II & non\_residential\_percent\_change\_from\_baseline III  \\
# \hline
# Intercept         & 1.95                                                & 13.67*                                               & 20.82**                                                \\
#                   & (9.66)                                              & (8.06)                                               & (9.61)                                                 \\
# R-squared         & 0.40                                                & 0.35                                                 & 0.25                                                   \\
# R-squared Adj.    & 0.37                                                & 0.33                                                 & 0.22                                                   \\
# StringencyIndex   & -0.54***                                            & -0.64***                                             & -0.59***                                               \\
#                   & (0.14)                                              & (0.14)                                               & (0.15)                                                 \\
# covid\_conspiracy &                                                     &                                                      & 0.07                                                   \\
#                   &                                                     &                                                      & (0.09)                                                 \\
# covid\_hoax       &                                                     & 0.26***                                              &                                                        \\
#                   &                                                     & (0.09)                                               &                                                        \\
# plandemic         & 0.33***                                             &                                                      &                                                        \\
#                   & (0.09)                                              &                                                      &                                                        \\
# \hline
# \end{tabular}
# \end{center}
# \end{table}

# %%
us_cross_sectional["non_residential_percent_change_from_baseline"].std()
# Out:
# 13.584944767366649

# %%
us_cross_sectional["StringencyIndex"].std()
# Out:
# 10.264002730555783

# %% [markdown]
# It looks like popularity of terms like "plandemic" is a good predictor of high mobility, after controlling for containment index.

# %% [markdown]
# ### Panel regressions: on op

# %% [markdown]
# #### Pooled OLS

# %%
us_monthly.columns
# Out:
# Index(['state', 'covid_conspiracy', 'covid_hoax', 'pizzagate', 'plandemic',
#        'wuhan_lab', 'positive', 'probableCases', 'negative', 'pending',
#        'totalTestResults', 'hospitalizedCurrently', 'hospitalizedCumulative',
#        'inIcuCurrently', 'inIcuCumulative', 'onVentilatorCurrently',
#        'onVentilatorCumulative', 'recovered', 'totalTestsViral',
#        'positiveTestsViral', 'negativeTestsViral', 'positiveCasesViral',
#        'deathConfirmed', 'deathProbable', 'totalTestEncountersViral',
#        'totalTestsPeopleViral', 'totalTestsAntibody', 'positiveTestsAntibody',
#        'negativeTestsAntibody', 'totalTestsPeopleAntibody',
#        'positiveTestsPeopleAntibody', 'negativeTestsPeopleAntibody',
#        'totalTestsPeopleAntigen', 'positiveTestsPeopleAntigen',
#        'totalTestsAntigen', 'positiveTestsAntigen', 'fips', 'positiveIncrease',
#        'negativeIncrease', 'total', 'totalTestResultsIncrease', 'posNeg',
#        'dataQualityGrade', 'deathIncrease', 'hospitalizedIncrease',
#        'commercialScore', 'negativeRegularScore', 'negativeScore',
#        'positiveScore', 'score', 'grade',
#        'retail_and_recreation_percent_change_from_baseline',
#        'grocery_and_pharmacy_percent_change_from_baseline',
#        'parks_percent_change_from_baseline',
#        'transit_stations_percent_change_from_baseline',
#        'workplaces_percent_change_from_baseline',
#        'residential_percent_change_from_baseline',
#        'non_residential_percent_change_from_baseline', 'C1_School closing',
#        'C1_Flag', 'C2_Workplace closing', 'C2_Flag', 'C3_Cancel public events',
#        'C3_Flag', 'C4_Restrictions on gatherings', 'C4_Flag',
#        'C5_Close public transport', 'C5_Flag', 'C6_Stay at home requirements',
#        'C6_Flag', 'C7_Restrictions on internal movement', 'C7_Flag',
#        'C8_International travel controls', 'ConfirmedCases', 'ConfirmedDeaths',
#        'StringencyIndex', 'GovernmentResponseIndex', 'ContainmentHealthIndex',
#        'pop_2019', 'GDP_2019'],
#       dtype='object')

# %%
us_monthly[["non_residential_percent_change_from_baseline"]].shift(1)
# Out:
#             non_residential_percent_change_from_baseline
# date
# 2020-03-31                                           NaN
# 2020-03-31                                     -1.880000
# 2020-03-31                                     -7.107692
# 2020-03-31                                    -10.207143
# 2020-03-31                                      1.300000
# ...                                                  ...
# 2021-01-31                                    -26.858065
# 2021-01-31                                    -24.741935
# 2021-01-31                                    -26.290323
# 2021-01-31                                    -18.032258
# 2021-01-31                                    -17.329032
#
# [561 rows x 1 columns]

# %%
val = (
    us_monthly[["state", "covid_conspiracy", "covid_hoax", "pizzagate", "plandemic", "wuhan_lab"]]
    .groupby("state")
    .resample("M")
    .asfreq()
).groupby(level=0).shift(1)

# %%
pd.DataFrame(val.to_records(index=False))
# Out:
#        state  covid_conspiracy  covid_hoax  pizzagate  plandemic  wuhan_lab
# 0        NaN               NaN         NaN        NaN        NaN        NaN
# 1    Alabama              29.0        10.0       76.0        NaN       33.0
# 2    Alabama              44.0        37.0       48.0        NaN       54.0
# 3    Alabama              33.0        14.0       15.0       45.0       44.0
# 4    Alabama               NaN        51.0       71.0       57.0       29.0
# ..       ...               ...         ...        ...        ...        ...
# 556  Wyoming               NaN         NaN       50.0        NaN        NaN
# 557  Wyoming               NaN         NaN       77.0        NaN        NaN
# 558  Wyoming               NaN         NaN      100.0        NaN        NaN
# 559  Wyoming              95.0         NaN        NaN        NaN        NaN
# 560  Wyoming               NaN         NaN        NaN        NaN      100.0
#
# [561 rows x 6 columns]

# %%
us_monthly = us_monthly.reset_index().set_index(["state", "date"])

# %%
us_monthly["StringencyIndex_times_plandemic"] = us_monthly["StringencyIndex"] * us_monthly["plandemic"]

# %%
exog_vars = ["plandemic", "StringencyIndex"]
exog = sm.add_constant(us_monthly[exog_vars])
mod = PooledOLS(us_monthly.non_residential_percent_change_from_baseline, exog)
pooled_res = mod.fit()
print(pooled_res)
# Out:
#                                        PooledOLS Estimation Summary
# ==========================================================================================================
# Dep. Variable:     non_residential_percent_change_from_baseline   R-squared:                        0.2065
# Estimator:                                            PooledOLS   R-squared (Between):              0.3083
# No. Observations:                                           332   R-squared (Within):               0.0506
# Date:                                          Sat, Feb 20 2021   R-squared (Overall):              0.2065
# Time:                                                  10:37:13   Log-likelihood                   -1425.2
# Cov. Estimator:                                      Unadjusted
#                                                                   F-statistic:                      42.817
# Entities:                                                    50   P-value                           0.0000
# Avg Obs:                                                 6.6400   Distribution:                   F(2,329)
# Min Obs:                                                 1.0000
# Max Obs:                                                 11.000   F-statistic (robust):             42.817
#                                                                   P-value                           0.0000
# Time periods:                                                11   Distribution:                   F(2,329)
# Avg Obs:                                                 30.182
# Min Obs:                                                 3.0000
# Max Obs:                                                 50.000
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# const               20.532     4.0652     5.0507     0.0000      12.535      28.529
# plandemic           0.2368     0.0415     5.7031     0.0000      0.1551      0.3185
# StringencyIndex    -0.6105     0.0754    -8.1017     0.0000     -0.7587     -0.4623
# ===================================================================================

# %%
pooled_res.summary.as_latex()
# Out:
# '\\begin{center}\n\\begin{tabular}{lclc}\n\\toprule\n\\textbf{Dep. Variable:}                    & non\\_residential\\_percent\\_change\\_from\\_baseline & \\textbf{  R-squared:         }   &      0.2260      \\\\\n\\textbf{Estimator:}                        &                      PanelOLS                     & \\textbf{  R-squared (Between):}  &      0.2856      \\\\\n\\textbf{No. Observations:}                 &                        332                        & \\textbf{  R-squared (Within):}   &      0.0723      \\\\\n\\textbf{Date:}                             &                  Sat, Feb 20 2021                 & \\textbf{  R-squared (Overall):}  &      0.2016      \\\\\n\\textbf{Time:}                             &                      10:44:20                     & \\textbf{  Log-likelihood     }   &     -1340.3      \\\\\n\\textbf{Cov. Estimator:}                   &                     Unadjusted                    & \\textbf{                     }   &                  \\\\\n\\textbf{}                                  &                                                   & \\textbf{  F-statistic:       }   &      30.947      \\\\\n\\textbf{Entities:}                         &                         50                        & \\textbf{  P-value            }   &      0.0000      \\\\\n\\textbf{Avg Obs:}                          &                       6.6400                      & \\textbf{  Distribution:      }   &     F(3,318)     \\\\\n\\textbf{Min Obs:}                          &                       1.0000                      & \\textbf{                     }   &                  \\\\\n\\textbf{Max Obs:}                          &                       11.000                      & \\textbf{  F-statistic (robust):} &      30.947      \\\\\n\\textbf{}                                  &                                                   & \\textbf{  P-value            }   &      0.0000      \\\\\n\\textbf{Time periods:}                     &                         11                        & \\textbf{  Distribution:      }   &     F(3,318)     \\\\\n\\textbf{Avg Obs:}                          &                       30.182                      & \\textbf{                     }   &                  \\\\\n\\textbf{Min Obs:}                          &                       3.0000                      & \\textbf{                     }   &                  \\\\\n\\textbf{Max Obs:}                          &                       50.000                      & \\textbf{                     }   &                  \\\\\n\\bottomrule\n\\end{tabular}\n\\begin{tabular}{lcccccc}\n                                           & \\textbf{Parameter} & \\textbf{Std. Err.} & \\textbf{T-stat} & \\textbf{P-value} & \\textbf{Lower CI} & \\textbf{Upper CI}  \\\\\n\\midrule\n\\textbf{const}                             &       13.877       &       6.2884       &      2.2067     &      0.0280      &       1.5048      &       26.249       \\\\\n\\textbf{plandemic}                         &       0.3623       &       0.1344       &      2.6951     &      0.0074      &       0.0978      &       0.6268       \\\\\n\\textbf{StringencyIndex}                   &      -0.4379       &       0.1184       &     -3.6980     &      0.0003      &      -0.6708      &      -0.2049       \\\\\n\\textbf{StringencyIndex\\_times\\_plandemic} &      -0.0037       &       0.0025       &     -1.4900     &      0.1372      &      -0.0085      &       0.0012       \\\\\n\\bottomrule\n\\end{tabular}\n%\\caption{PanelOLS Estimation Summary}\n\\end{center}\n\nF-test for Poolability: 21.097 \\newline\n P-value: 0.0000 \\newline\n Distribution: F(10,318) \\newline\n  \\newline\n Included effects: Time'

# %%
us_monthly["plandemic"].std()
# Out:
# 23.85524463086154

# %% [markdown]
# #### Fixed effects

# %%
exog_vars = ["plandemic", "StringencyIndex"]
exog = sm.add_constant(us_monthly[exog_vars])
mod = PanelOLS(us_monthly.non_residential_percent_change_from_baseline, exog, time_effects=True)
fixed_res = mod.fit()
print(fixed_res)
# Out:
#                                        PanelOLS Estimation Summary
# ==========================================================================================================
# Dep. Variable:     non_residential_percent_change_from_baseline   R-squared:                        0.2206
# Estimator:                                             PanelOLS   R-squared (Between):              0.2821
# No. Observations:                                           332   R-squared (Within):               0.0686
# Date:                                          Sat, Feb 20 2021   R-squared (Overall):              0.2003
# Time:                                                  10:48:07   Log-likelihood                   -1341.5
# Cov. Estimator:                                      Unadjusted
#                                                                   F-statistic:                      45.138
# Entities:                                                    50   P-value                           0.0000
# Avg Obs:                                                 6.6400   Distribution:                   F(2,319)
# Min Obs:                                                 1.0000
# Max Obs:                                                 11.000   F-statistic (robust):             45.138
#                                                                   P-value                           0.0000
# Time periods:                                                11   Distribution:                   F(2,319)
# Avg Obs:                                                 30.182
# Min Obs:                                                 3.0000
# Max Obs:                                                 50.000
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# const               21.133     3.9866     5.3009     0.0000      13.289      28.976
# plandemic           0.1703     0.0384     4.4385     0.0000      0.0948      0.2458
# StringencyIndex    -0.5800     0.0703    -8.2529     0.0000     -0.7183     -0.4417
# ===================================================================================
#
# F-test for Poolability: 20.928
# P-value: 0.0000
# Distribution: F(10,319)
#
# Included effects: Time

# %%
fixed_res.summary.as_latex()
# Out:
# '\\begin{center}\n\\begin{tabular}{lclc}\n\\toprule\n\\textbf{Dep. Variable:}    & non\\_residential\\_percent\\_change\\_from\\_baseline & \\textbf{  R-squared:         }   &      0.2206      \\\\\n\\textbf{Estimator:}        &                      PanelOLS                     & \\textbf{  R-squared (Between):}  &      0.2821      \\\\\n\\textbf{No. Observations:} &                        332                        & \\textbf{  R-squared (Within):}   &      0.0686      \\\\\n\\textbf{Date:}             &                  Sat, Feb 20 2021                 & \\textbf{  R-squared (Overall):}  &      0.2003      \\\\\n\\textbf{Time:}             &                      10:48:07                     & \\textbf{  Log-likelihood     }   &     -1341.5      \\\\\n\\textbf{Cov. Estimator:}   &                     Unadjusted                    & \\textbf{                     }   &                  \\\\\n\\textbf{}                  &                                                   & \\textbf{  F-statistic:       }   &      45.138      \\\\\n\\textbf{Entities:}         &                         50                        & \\textbf{  P-value            }   &      0.0000      \\\\\n\\textbf{Avg Obs:}          &                       6.6400                      & \\textbf{  Distribution:      }   &     F(2,319)     \\\\\n\\textbf{Min Obs:}          &                       1.0000                      & \\textbf{                     }   &                  \\\\\n\\textbf{Max Obs:}          &                       11.000                      & \\textbf{  F-statistic (robust):} &      45.138      \\\\\n\\textbf{}                  &                                                   & \\textbf{  P-value            }   &      0.0000      \\\\\n\\textbf{Time periods:}     &                         11                        & \\textbf{  Distribution:      }   &     F(2,319)     \\\\\n\\textbf{Avg Obs:}          &                       30.182                      & \\textbf{                     }   &                  \\\\\n\\textbf{Min Obs:}          &                       3.0000                      & \\textbf{                     }   &                  \\\\\n\\textbf{Max Obs:}          &                       50.000                      & \\textbf{                     }   &                  \\\\\n\\bottomrule\n\\end{tabular}\n\\begin{tabular}{lcccccc}\n                         & \\textbf{Parameter} & \\textbf{Std. Err.} & \\textbf{T-stat} & \\textbf{P-value} & \\textbf{Lower CI} & \\textbf{Upper CI}  \\\\\n\\midrule\n\\textbf{const}           &       21.133       &       3.9866       &      5.3009     &      0.0000      &       13.289      &       28.976       \\\\\n\\textbf{plandemic}       &       0.1703       &       0.0384       &      4.4385     &      0.0000      &       0.0948      &       0.2458       \\\\\n\\textbf{StringencyIndex} &      -0.5800       &       0.0703       &     -8.2529     &      0.0000      &      -0.7183      &      -0.4417       \\\\\n\\bottomrule\n\\end{tabular}\n%\\caption{PanelOLS Estimation Summary}\n\\end{center}\n\nF-test for Poolability: 20.928 \\newline\n P-value: 0.0000 \\newline\n Distribution: F(10,319) \\newline\n  \\newline\n Included effects: Time'

# %%
exog_vars = ["plandemic", "StringencyIndex", "StringencyIndex_times_plandemic"]
exog = sm.add_constant(us_monthly[exog_vars])
mod = PanelOLS(us_monthly.non_residential_percent_change_from_baseline, exog, time_effects=True)
pooled_res = mod.fit()
print(pooled_res)
# Out:
#                                        PanelOLS Estimation Summary
# ==========================================================================================================
# Dep. Variable:     non_residential_percent_change_from_baseline   R-squared:                        0.2260
# Estimator:                                             PanelOLS   R-squared (Between):              0.2856
# No. Observations:                                           332   R-squared (Within):               0.0723
# Date:                                          Sat, Feb 20 2021   R-squared (Overall):              0.2016
# Time:                                                  10:44:20   Log-likelihood                   -1340.3
# Cov. Estimator:                                      Unadjusted
#                                                                   F-statistic:                      30.947
# Entities:                                                    50   P-value                           0.0000
# Avg Obs:                                                 6.6400   Distribution:                   F(3,318)
# Min Obs:                                                 1.0000
# Max Obs:                                                 11.000   F-statistic (robust):             30.947
#                                                                   P-value                           0.0000
# Time periods:                                                11   Distribution:                   F(3,318)
# Avg Obs:                                                 30.182
# Min Obs:                                                 3.0000
# Max Obs:                                                 50.000
#
#                                         Parameter Estimates
# ===================================================================================================
#                                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------------------------
# const                               13.877     6.2884     2.2067     0.0280      1.5048      26.249
# plandemic                           0.3623     0.1344     2.6951     0.0074      0.0978      0.6268
# StringencyIndex                    -0.4379     0.1184    -3.6980     0.0003     -0.6708     -0.2049
# StringencyIndex_times_plandemic    -0.0037     0.0025    -1.4900     0.1372     -0.0085      0.0012
# ===================================================================================================
#
# F-test for Poolability: 21.097
# P-value: 0.0000
# Distribution: F(10,318)
#
# Included effects: Time

# %% [markdown]
# #### Panel regression: add lagging

# %%
us_monthly["plandemic_l1"] = list(us_monthly[["plandemic"]].reset_index().sort_values("date").set_index("date").groupby("state").shift()["plandemic"]) # Lagging "plandemic" variable

# %%
us_monthly["StringencyIndex_times_plandemic_l1"] = us_monthly["StringencyIndex"] * us_monthly["plandemic_l1"]

# %%
exog_vars = ["plandemic_l1", "StringencyIndex"]
exog = sm.add_constant(us_monthly[exog_vars])
mod = PooledOLS(us_monthly.non_residential_percent_change_from_baseline, exog)
pooled_res = mod.fit()
print(pooled_res)

# %%
exog_vars = ["plandemic_l1", "StringencyIndex"]
exog = sm.add_constant(us_monthly[exog_vars])
mod = PanelOLS(us_monthly.non_residential_percent_change_from_baseline, exog, entity_effects=True)
pooled_res = mod.fit()
print(pooled_res)

# %%
exog_vars = ["plandemic_l1", "plandemic", "StringencyIndex"]
exog = sm.add_constant(us_monthly[exog_vars])
mod = PanelOLS(us_monthly.non_residential_percent_change_from_baseline, exog, entity_effects=True)
pooled_res = mod.fit()
print(pooled_res)

# %%
exog_vars = ["plandemic_l1", "StringencyIndex"]
exog = sm.add_constant(us_monthly[exog_vars])
mod = PanelOLS(us_monthly.non_residential_percent_change_from_baseline, exog, time_effects=True)
pooled_res = mod.fit()
print(pooled_res)

# %%
exog_vars = ["plandemic_l1", "StringencyIndex_times_plandemic_l1", "StringencyIndex"]
exog = sm.add_constant(us_monthly[exog_vars])
mod = PanelOLS(us_monthly.non_residential_percent_change_from_baseline, exog, time_effects=True)
pooled_res = mod.fit()
print(pooled_res)

# %%
exog_vars = ["plandemic_l1", "StringencyIndex_times_plandemic_l1", "StringencyIndex"]
exog = sm.add_constant(us_monthly[exog_vars])
mod = PanelOLS(us_monthly.non_residential_percent_change_from_baseline, exog, entity_effects=True)
pooled_res = mod.fit()
print(pooled_res)

# %%
exog_vars = ["plandemic_l1", "StringencyIndex_times_plandemic_l1", "StringencyIndex"]
exog = sm.add_constant(us_monthly[exog_vars])
mod = PanelOLS(us_monthly.non_residential_percent_change_from_baseline, exog, entity_effects=True, time_effects=True)
pooled_res = mod.fit()
print(pooled_res)

# %%
exog_vars = ["plandemic", "StringencyIndex_times_plandemic", "plandemic_l1", "StringencyIndex_times_plandemic_l1", "StringencyIndex"]
exog = sm.add_constant(us_monthly[exog_vars])
mod = PanelOLS(us_monthly.non_residential_percent_change_from_baseline, exog, entity_effects=True)
pooled_res = mod.fit()
print(pooled_res)

# %%
exog_vars = ["plandemic", "StringencyIndex_times_plandemic", "plandemic_l1", "StringencyIndex_times_plandemic_l1", "StringencyIndex"]
exog = sm.add_constant(us_monthly[exog_vars])
mod = PanelOLS(us_monthly.non_residential_percent_change_from_baseline, exog, time_effects=True)
pooled_res = mod.fit()
print(pooled_res)

# %%
exog_vars = ["plandemic", "StringencyIndex_times_plandemic", "plandemic_l1", "StringencyIndex_times_plandemic_l1", "StringencyIndex"]
exog = sm.add_constant(us_monthly[exog_vars])
mod = PanelOLS(us_monthly.non_residential_percent_change_from_baseline, exog, entity_effects=True, time_effects=True)
pooled_res = mod.fit()
print(pooled_res)

# %% [markdown]
# ### Panel regressions: on outcomes
